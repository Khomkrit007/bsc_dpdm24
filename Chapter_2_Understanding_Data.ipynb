# %% [markdown]
# <a href="https://colab.research.google.com/github/Khomkrit007/bsc_dpdm24/blob/main/Chapter_2_Understanding_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Import data CSV

# %%
# prompt: เชื่อมต่อไปยัง drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/มหาลัยขอนแก่น/3-2/Data prepare & Data Mining/bsc_dpdm24_data/tis_name_02122567.csv'
df = pd.read_csv(file_path, encoding='cp874')
print(df.head())
# Out:
#    ลำดับ    เลขที่ มอก.                                  ชื่อ มอก. ภาษาไทย  \
# 0      1         2-2525              ขวดแก้วสำหรับเครื่องดื่มประเภทอัดก๊าซ
# 1      2         3-2562                                             น้ำปลา
# 2      3  4 เล่ม 1-2558  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
# 3      4  4 เล่ม 2-2552  วิธีมาตรฐานในการวัดอุณหภูมิที่เพิ่มขึ้นของขั้ว...
# 4      5  4 เล่ม 3-2563  หลอดไฟฟ้าไส้ทังสเตนสำหรับใช้ในที่อยู่อาศัยและท...
#
#                                 ชื่อ มอก. ภาษาอังกฤษ ประเภทมาตรฐาน  \
# 0                        Aerated water glass bottles        ทั่วไป
# 1                                         Fish sauce        ทั่วไป
# 2  Tungsten filament lamps for domestics and simi...        บังคับ
# 3  Standard method of measurement of lamp cap tem...        ทั่วไป
# 4  Tungsten filament lamps for domestics and simi...        ทั่วไป
#
#    กลุ่มผลิตภัณฑ์ ชนิดมาตรฐาน BCG Economy ประกาศกระทรวงฯ วันที่  \
# ...

# %% [markdown]
# #Import data Excel

# %%
file_path = '/content/drive/MyDrive/มหาลัยขอนแก่น/3-2/Data prepare & Data Mining/bsc_dpdm24_data/export62_64.xlsx'

# Try to read the file as Excel
try:
    df = pd.read_excel(file_path, engine='openpyxl')  # Use 'openpyxl' engine for .xlsx files
    print("Successfully read as Excel:")
    print(df.head())
except FileNotFoundError: # Correct indentation for except block
    print(f"Error: File not found at {file_path}")
except Exception as e: # Correct indentation for except block
    print(f"Error reading Excel file: {e}")
# Out:
# Successfully read as Excel:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2562            1              1012900          0               C62
# 1      2562            1              1022100          1               C62
# 2      2562            1              1022100          2               C62
# 3      2562            1              1022919          0               C62
# 4      2562            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0          อื่น ๆ                       Other                    7
# 1        โคตัวผู้                 Bullocks                    6663
# 2       โคตัวเมีย                        Cows                   36
# 3          อื่น ๆ                       Other                16983
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                  746
#
#    มูลค่าส่งออกเงินบาท
# 0               105000
# 1            119934000
# ...

# %%
df
# Out:
#         ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ  \
# 0           2562            1              1012900          0
# 1           2562            1              1022100          1
# 2           2562            1              1022100          2
# 3           2562            1              1022919          0
# 4           2562            1              1023100          0
# ...          ...          ...                  ...        ...
# 103273      2562           12             97030000          7
# 103274      2562           12             97030000         90
# 103275      2562           12             97040000          0
# 103276      2562           12             97050010          1
# 103277      2562           12             97050090          0
#
#        หน่วยตามรหัสสถิติ                                        คำอธิบายไทย  \
# 0                    C62                                             อื่น ๆ
# ...

# %% [markdown]
# expected problum:table location

# %%
# prompt: ดึงข้อมูล sheet 64

try:
    # Specify the sheet name
    df1 = pd.read_excel(file_path, sheet_name='Export 64', engine='openpyxl')
    print("Successfully read sheet '64' from Excel:")
    print(df.head())
except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except ValueError as e: # Catch ValueError for invalid sheet name
    print(f"Error: {e}") # Print the specific error message
except Exception as e:
    print(f"Error reading Excel file: {e}")
# Out:
# Successfully read sheet '64' from Excel:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2562            1              1012900          0               C62
# 1      2562            1              1022100          1               C62
# 2      2562            1              1022100          2               C62
# 3      2562            1              1022919          0               C62
# 4      2562            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0          อื่น ๆ                       Other                    7
# 1        โคตัวผู้                 Bullocks                    6663
# 2       โคตัวเมีย                        Cows                   36
# 3          อื่น ๆ                       Other                16983
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                  746
#
#    มูลค่าส่งออกเงินบาท
# 0               105000
# ...

# %%
df1
# Out:
#       Unnamed: 0 Unnamed: 1   Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0            NaN  Export 64          NaN                  NaN        NaN
# 1            NaN   ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 2            NaN       2564            1             01012100        000
# 3            NaN       2564            1             01012900        000
# 4            NaN       2564            1             01022100        001
# ...          ...        ...          ...                  ...        ...
# 1375         NaN       2564            1             25309090        005
# 1376         NaN       2564            1             25309090        090
# 1377         NaN       2564            1             26011110        000
# 1378         NaN       2564            1             26011190        000
# 1379         NaN       2564            1             26011290        000
#
#              Unnamed: 5            Unnamed: 6                  Unnamed: 7  \
# ...

# %%
# prompt: open sheet number 3 of the excel file and select only the table part

try:
    # Specify the sheet by index (0-based)
    df_sheet3 = pd.read_excel(file_path, sheet_name=2, engine='openpyxl')  # Sheet 3 is index 2

    # Assuming the table starts from a specific cell (adjust as needed)
    # Example: Table starts from row 5, column 0
    # You'll need to inspect your excel to find the correct values
    start_row = 4
    start_col = 0

    # Adjust these values based on the actual end of your table data
    end_row = df_sheet3.shape[0] # Read till the end of the excel file
    end_col = df_sheet3.shape[1] # Read till the end of the excel file

    # Select only the table data
    df_table = df_sheet3.iloc[start_row:end_row, start_col:end_col]

    print("Successfully read sheet 3 (index 2) and selected table data:")
    print(df_table.head())

except FileNotFoundError:
    print(f"Error: File not found at {file_path}")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error reading Excel file: {e}")
# Out:
# Successfully read sheet 3 (index 2) and selected table data:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4         NaN       2564          1   01022100        001        C62
# 5         NaN       2564          1   01022919        000        C62
# 6         NaN       2564          1   01023100        000        C62
# 7         NaN       2564          1   01023900        000        C62
# 8         NaN       2564          1   01031000        000        C62
#
#        Unnamed: 6                  Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 4        โคตัวผู้                 Bullocks          9674  145263681
# 5          อื่น ๆ                       Other      10976  199947461
# 6  สำหรับทำพันธุ์  Pure-bred breeding animals       3169   51784330
# 7          อื่น ๆ                       Other        278    7089000
# 8  สำหรับทำพันธุ์  Pure-bred breeding animals      70940  394406939
#
#    Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# ...

# %%
df_table
# Out:
#       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 4            NaN       2564          1   01022100        001        C62
# 5            NaN       2564          1   01022919        000        C62
# 6            NaN       2564          1   01023100        000        C62
# 7            NaN       2564          1   01023900        000        C62
# 8            NaN       2564          1   01031000        000        C62
# ...          ...        ...        ...        ...        ...        ...
# 1375         NaN       2564          1   25309090        005        KGM
# 1376         NaN       2564          1   25309090        090        KGM
# 1377         NaN       2564          1   26011110        000        KGM
# 1378         NaN       2564          1   26011190        000        KGM
# 1379         NaN       2564          1   26011290        000        KGM
#
#                 Unnamed: 6                  Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# ...

# %%
df_sheet4 = pd.read_excel(file_path, sheet_name=2, skiprows=2,usecols=[1,2,3,4], engine='openpyxl')
df_sheet4.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ
# 0      2564            1              1012100          0
# 1      2564            1              1012900          0
# 2      2564            1              1022100          1
# 3      2564            1              1022919          0
# 4      2564            1              1023100          0

# %%
df_sheet5 = pd.read_excel(file_path, sheet_name=2, skiprows=2,usecols=range(1,10), engine='openpyxl')
df_sheet5.head()
# Out:
#    ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 0      2564            1              1012100          0               C62
# 1      2564            1              1012900          0               C62
# 2      2564            1              1022100          1               C62
# 3      2564            1              1022919          0               C62
# 4      2564            1              1023100          0               C62
#
#       คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 0  สำหรับทำพันธุ์  Pure-bred breeding animals                   44
# 1          อื่น ๆ                       Other                   35
# 2        โคตัวผู้                 Bullocks                    9674
# 3          อื่น ๆ                       Other                10976
# 4  สำหรับทำพันธุ์  Pure-bred breeding animals                 3169
#
#    มูลค่าส่งออกเงินบาท
# 0               196720
# 1               182000
# 2            145263681
# ...

# %%
df_sheet5.tail()
# Out:
#       ปีแม่แบบ  เดือนแม่แบบ  พิกัดศุลกากร 8 หลัก  รหัสสถิติ หน่วยตามรหัสสถิติ  \
# 1373      2564            1             25309090          5               KGM
# 1374      2564            1             25309090         90               KGM
# 1375      2564            1             26011110          0               KGM
# 1376      2564            1             26011190          0               KGM
# 1377      2564            1             26011290          0               KGM
#
#                คำอธิบายไทย                    คำอธิบาย  น้ำหนัก/ปริมาณสถิติ  \
# 1373        แร่ไพโรฟิลไรท์                 Pyrophylite               272000
# 1374                อื่น ๆ                       Other              2109246
# 1375  แร่เฮมาไทต์และหัวแร่  Haematite and concentrates             42930945
# 1376                อื่น ๆ                       Other                    5
# 1377                อื่น ๆ                       Other                   70
#
#       มูลค่าส่งออกเงินบาท
# ...

# %% [markdown]
# **Google Sheets**

# %% [markdown]
# #Import data Json

# %%
# prompt: open google sheets

from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# Open the spreadsheet (replace with your spreadsheet key)
# You can find the spreadsheet key in the URL of your spreadsheet
spreadsheet_key = 'YOUR_SPREADSHEET_KEY'  # Replace with your actual key
try:
    sh = gc.open_by_key(spreadsheet_key)
    print(f"Successfully opened spreadsheet: {sh.title}")

    # Select a worksheet (replace with your worksheet name or index)
    worksheet = sh.sheet1 # Or sh.get_worksheet(0) for the first sheet

    # Now you can work with the worksheet data
    # Example: read all values
    data = worksheet.get_all_values()
    print("Worksheet data:")
    print(data)


except gspread.SpreadsheetNotFound:
    print(f"Error: Spreadsheet with key '{spreadsheet_key}' not found.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Error: Spreadsheet with key 'YOUR_SPREADSHEET_KEY' not found.

# %%
import pandas as pd

file_path = '/content/drive/MyDrive/มหาลัยขอนแก่น/3-2/Data prepare & Data Mining/bsc_dpdm24_data/data_station.json'

# Try reading with 'utf-8' encoding first (most common)
try:
    df = pd.read_json(file_path, encoding='utf-8')
    print(df.head())
except UnicodeDecodeError:
    # If 'utf-8' fails, try 'latin-1' or other potential encodings
    try:
        df = pd.read_json(file_path, encoding='latin-1')
        print(df.head())
    except UnicodeDecodeError:
        # If other encodings fail, you may need to inspect the file
        # to determine the correct encoding or handle the problematic bytes
        print("Error: Could not decode JSON file with common encodings. "
              "Please check the file's encoding and try again.")
# Out:
#    id  station_code           name            en_name th_short en_short  \
# 0   1          1001        กรุงเทพ            Bangkok      กท.      BKK
# 1   2          1002          ยมราช           Yommaraj      ยช.      YMR
# 2   3          1004         สามเสน            Sam Sen      สส.      SAM
# 3   4          1006     ประดิพัทธ์          Pra Dipat     ปอิ.      PDP
# 4   5          1007  ชุมทางบางซื่อ  Bang Sue Junction      บซ.      BSJ
#
#   chname  controldivision  exact_km  exact_distance  km  class        lat  \
# 0     曼谷               14         0               0   0     11  13.739277
# 1    勇马拉               14         2               2   2     99          0
# 2     三森               14         5               4   4      1  13.779293
# 3    帕涤潘               14         6               6   6     99          0
# 4   邦苏总站               14         7               7   7      1    13.8043
#
#          long  active  giveway  dual_track  comment
# ...

# %%
df
# Out:
#       id  station_code             name            en_name th_short en_short  \
# 0      1          1001          กรุงเทพ            Bangkok      กท.      BKK
# 1      2          1002            ยมราช           Yommaraj      ยช.      YMR
# 2      3          1004           สามเสน            Sam Sen      สส.      SAM
# 3      4          1006       ประดิพัทธ์          Pra Dipat     ปอิ.      PDP
# 4      5          1007    ชุมทางบางซื่อ  Bang Sue Junction      บซ.      BSJ
# ..   ...           ...              ...                ...      ...      ...
# 686  687          5034        ทุ่งสีทอง     Thung Si Thong     ทอี.      TST
# 687  688          5035       คลองนกเล็ก     Khlong Nok Lek      ลเ.      KNL
# 688  689          7001       อลอร์สตาร์         Alor Setar     NULL     NULL
# 689  690          7002  บูกิตเมอร์ตายัน     Bukit Mertajam     NULL     NULL
# 690  691          7003   บัตเตอร์เวอร์ธ        Butterworth     NULL     NULL
#
# ...

# %%
file_path = '/content/drive/MyDrive/มหาลัยขอนแก่น/3-2/Data prepare & Data Mining/bsc_dpdm24_data/memo_2298.json'

# Try reading with 'utf-8' encoding first (most common)
try:
    import pandas as pd
    df = pd.read_json(file_path, encoding='utf-8')
    print(df.head())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
#    MemoId       DocumentNo  TemplateId            TemplateName  \
# 0    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
# 1    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
#
#                        ToPerson                   CcPerson  CreatorId  \
# 0  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
# 1  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
#
#                        CNameTh                     CNameEn  CPositionId  ...  \
# 0  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
# 1  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
#
#   Amount               RequestDate              ModifiedDate PersonWaitingId  \
# 0    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
# 1    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
#
#               PersonWaiting  CompanyId         CompanyName  CompletedDate  \
# ...

# %%
df
# Out:
#    MemoId       DocumentNo  TemplateId            TemplateName  \
# 0    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
# 1    2298  REQ-2019-002298        1050  แบบฟอร์มเบิกเงินสดย่อย
#
#                        ToPerson                   CcPerson  CreatorId  \
# 0  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
# 1  Mr. Suwittawat Ragsameorwong  Miss Soravee Ritgarunvong          8
#
#                        CNameTh                     CNameEn  CPositionId  ...  \
# 0  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
# 1  นางสาวเพิ่มสิน คุณวิสิฏสิริ  Miss Phoemsin Kunwisitsiri           16  ...
#
#   Amount               RequestDate              ModifiedDate PersonWaitingId  \
# 0    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
# 1    300  2019-03-21T08:43:47.490Z  2019-03-22T12:03:23.447Z             NaN
#
#               PersonWaiting  CompanyId         CompanyName  CompletedDate  \
# ...

# %% [markdown]
# ####quiz3
# print actor name and ActionProcess

# %%
import json

file_path = '/content/drive/MyDrive/มหาลัยขอนแก่น/3-2/Data prepare & Data Mining/bsc_dpdm24_data/memo_2298.json'

# Load the JSON data into a variable called json_2298
with open(file_path, 'r', encoding='utf-8') as f:
    json_2298 = json.load(f)

# Now you can access the data using json_2298
print(json_2298['ActionHistory'][0]['ActorName'], json_2298['ActionHistory'][0]['ActionProcess'])
# Out:
# นางสาวเพิ่มสิน คุณวิสิฏสิริ submit
